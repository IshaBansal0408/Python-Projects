# %%
from faker import Faker

faker = Faker()
for i in range(5):
    print(faker.name())

print()

faker1 = Faker('hi_IN')
for i in range(5):
    print(faker1.name())

print()
    
for i in range(5):
    print(faker.text())

print()

import pandas as pd
data = [faker.profile() for i in range(10)]
df = pd.DataFrame(data)

df.head()
# Out:
# Scott Conner
# Lauren Bradley
# Terri Barnes
# Nancy Johnston DVM
# Robert Harris
#
# गोविंदा रामलला
# किरण दवे
# बना, कुमारी
# गुप्ता, आन्वी
# वफादार, तन्वी
#
# Painting as vote short prepare goal. Training miss whatever yourself last goal bar. Style enough speak data scientist various return eat.
# Different magazine high bit.
# Author cup seven what main reduce often. Use remain respond school behind. Skin responsibility image audience.
# Prove throw during four measure. Safe action situation she. Say cost though true now himself citizen example.
# Newspaper ability require step read very seem. Side imagine president summer risk table service development.
# But worry all once because social.
# Board key class many some national. First list generation family.
# Color skill commercial ground seat. Test material concern easy power if executive.
# Minute hit box statement single mind impact.
#                              job                      company          ssn  \
# ...
