# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randint(0,100,size=(10, 8)), columns=list('ABCDEFGH'))

#Add some NaN values
df.iloc[3, 3] = np.nan
df.iloc[0, 2] = np.nan
df.iloc[1, 4] = np.nan
df.iloc[6, 3] = np.nan
df.iloc[0, 7] = np.nan

# %%
df
# Out:
#     A   B     C     D     E   F   G     H
# 0  50  64   NaN  68.0  30.0  49  25   NaN
# 1  68  49  35.0  15.0   NaN  45  82   0.0
# 2  42  50  28.0  51.0  32.0  69  68  72.0
# 3  57  65  13.0   NaN  56.0  44  19  58.0
# 4  10  44  92.0  44.0  75.0  18  48  38.0
# 5  78  96  11.0  12.0  35.0  91   1  12.0
# 6  24  80  60.0   NaN   9.0  34  43  33.0
# 7  28  33  90.0   1.0  31.0  98  46  26.0
# 8  58  92  26.0  58.0  80.0  60  28  67.0
# 9  48   5  81.0  26.0  53.0  16  65  12.0

# %%
df.style.highlight_min(color='yellow').highlight_max(color='green')
# Out:
# <style type="text/css">
# #T_a6776_row0_col3, #T_a6776_row1_col6, #T_a6776_row2_col7, #T_a6776_row4_col2, #T_a6776_row5_col0, #T_a6776_row5_col1, #T_a6776_row7_col5, #T_a6776_row8_col4 {
#   background-color: green;
# }
# #T_a6776_row1_col7, #T_a6776_row4_col0, #T_a6776_row5_col2, #T_a6776_row5_col6, #T_a6776_row6_col4, #T_a6776_row7_col3, #T_a6776_row9_col1, #T_a6776_row9_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a6776_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#       <th class="col_heading level0 col6" >G</th>
#       <th class="col_heading level0 col7" >H</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df.style.highlight_min(
    color='yellow').highlight_max(
        color='green').highlight_null(
            null_color="red")
# Out:
# <style type="text/css">
# #T_71531_row0_col2, #T_71531_row0_col7, #T_71531_row1_col4, #T_71531_row3_col3, #T_71531_row6_col3 {
#   background-color: red;
# }
# #T_71531_row0_col3, #T_71531_row1_col6, #T_71531_row2_col7, #T_71531_row4_col2, #T_71531_row5_col0, #T_71531_row5_col1, #T_71531_row7_col5, #T_71531_row8_col4 {
#   background-color: green;
# }
# #T_71531_row1_col7, #T_71531_row4_col0, #T_71531_row5_col2, #T_71531_row5_col6, #T_71531_row6_col4, #T_71531_row7_col3, #T_71531_row9_col1, #T_71531_row9_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_71531_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
# ...

# %%
df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_22065_row0_col0 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_22065_row0_col1, #T_22065_row2_col5 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_22065_row0_col2, #T_22065_row0_col7, #T_22065_row1_col4, #T_22065_row3_col3, #T_22065_row6_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_22065_row0_col3, #T_22065_row1_col6, #T_22065_row2_col7, #T_22065_row4_col2, #T_22065_row5_col0, #T_22065_row5_col1, #T_22065_row7_col5, #T_22065_row8_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_22065_row0_col4, #T_22065_row0_col6, #T_22065_row1_col2 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_22065_row0_col5 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_22065_row1_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_22065_row1_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_22065_row1_col3, #T_22065_row2_col2 {
# ...

# %%
df.style.background_gradient(cmap="rainbow")
# Out:
# <style type="text/css">
# #T_1f4a9_row0_col0 {
#   background-color: #acf59a;
#   color: #000000;
# }
# #T_1f4a9_row0_col1, #T_1f4a9_row2_col5 {
#   background-color: #cbe486;
#   color: #000000;
# }
# #T_1f4a9_row0_col2, #T_1f4a9_row0_col7, #T_1f4a9_row1_col4, #T_1f4a9_row3_col3, #T_1f4a9_row6_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_1f4a9_row0_col3, #T_1f4a9_row1_col6, #T_1f4a9_row2_col7, #T_1f4a9_row4_col2, #T_1f4a9_row5_col0, #T_1f4a9_row5_col1, #T_1f4a9_row7_col5, #T_1f4a9_row8_col4 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_1f4a9_row0_col4, #T_1f4a9_row0_col6, #T_1f4a9_row1_col2 {
#   background-color: #17cbe4;
#   color: #000000;
# }
# #T_1f4a9_row0_col5 {
#   background-color: #4ef3cd;
#   color: #000000;
# }
# #T_1f4a9_row1_col0 {
#   background-color: #ff703a;
#   color: #f1f1f1;
# }
# #T_1f4a9_row1_col1 {
#   background-color: #76ffb9;
#   color: #000000;
# }
# #T_1f4a9_row1_col3, #T_1f4a9_row2_col2 {
# ...

# %%
df.style.bar(color="pink")
# Out:
# <style type="text/css">
# #T_a1e4d_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 58.8%, transparent 58.8%);
# }
# #T_a1e4d_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 64.8%, transparent 64.8%);
# }
# #T_a1e4d_row0_col3, #T_a1e4d_row1_col6, #T_a1e4d_row2_col7, #T_a1e4d_row4_col2, #T_a1e4d_row5_col0, #T_a1e4d_row5_col1, #T_a1e4d_row7_col5, #T_a1e4d_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 100.0%, transparent 100.0%);
# }
# #T_a1e4d_row0_col4, #T_a1e4d_row0_col6, #T_a1e4d_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 29.6%, transparent 29.6%);
# }
# #T_a1e4d_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 40.2%, transparent 40.2%);
# }
# #T_a1e4d_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,pink 85.3%, transparent 85.3%);
# }
# ...
