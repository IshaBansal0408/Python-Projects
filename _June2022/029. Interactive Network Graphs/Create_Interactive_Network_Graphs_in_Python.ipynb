# %%
# %%capture
# !pip install pyvis

# %% [markdown]
# # Import Libraries

# %%
from pyvis import network as net
from IPython.core.display import display, HTML
import random

# %% [markdown]
# # Only Nodes

# %%
g_only_nodes =  net.Network(height='600px',width='90%',
                  bgcolor='white',font_color="red",
                  heading="Networkx Graph with only Nodes")

for i in range(1,11):  
  g_only_nodes.add_node(i)

g_only_nodes.show('Only_Nodes.html')
display(HTML('Only_Nodes.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>Networkx Graph with only Nodes</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 90%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"font": {"color": "red"}, "id": 1, "label": 1, "shape": "dot"}, {"font": {"color": "red"}, "id": 2, "label": 2, "shape": "dot"}, {"font": {"color": "red"}, "id": 3, "label": 3, "shape": "dot"}, {"font": {"color": "red"}, "id": 4, "label": 4, "shape": "dot"}, {"font": {"color": "red"}, "id": 5, "label": 5, "shape": "dot"}, {"font": {"color": "red"}, "id": 6, "label": 6, "shape": "dot"}, {"font": {"color": "red"}, "id": 7, "label": 7, "shape": "dot"}, {"font": {"color": "red"}, "id": 8, "label": 8, "shape": "dot"}, {"font": {"color": "red"}, "id": 9, "label": 9, "shape": "dot"}, {"font": {"color": "red"}, "id": 10, "label": 10, "shape": "dot"}]);
#         edges = new vis.DataSet([]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Added Edges

# %%
def generate_edge():
  s = random.randint(1,10)
  d = random.randint(1,10)
  return (s,d)

g =  net.Network(height='600px',width='90%',
                  bgcolor='white',font_color="red",
                  heading="A Simple Networkx Graph")

for i in range(1,11):  
  g.add_node(i)

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g.add_edge(eg[0],eg[1])
      i+=1

g.show('Simple_Network_Graph.html')
display(HTML('Simple_Network_Graph.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>A Simple Networkx Graph</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 90%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"font": {"color": "red"}, "id": 1, "label": 1, "shape": "dot"}, {"font": {"color": "red"}, "id": 2, "label": 2, "shape": "dot"}, {"font": {"color": "red"}, "id": 3, "label": 3, "shape": "dot"}, {"font": {"color": "red"}, "id": 4, "label": 4, "shape": "dot"}, {"font": {"color": "red"}, "id": 5, "label": 5, "shape": "dot"}, {"font": {"color": "red"}, "id": 6, "label": 6, "shape": "dot"}, {"font": {"color": "red"}, "id": 7, "label": 7, "shape": "dot"}, {"font": {"color": "red"}, "id": 8, "label": 8, "shape": "dot"}, {"font": {"color": "red"}, "id": 9, "label": 9, "shape": "dot"}, {"font": {"color": "red"}, "id": 10, "label": 10, "shape": "dot"}]);
#         edges = new vis.DataSet([{"from": 1, "to": 7}, {"from": 7, "to": 3}, {"from": 9, "to": 4}, {"from": 3, "to": 1}, {"from": 3, "to": 2}, {"from": 1, "to": 6}, {"from": 5, "to": 3}, {"from": 3, "to": 10}, {"from": 4, "to": 1}, {"from": 7, "to": 4}, {"from": 9, "to": 10}, {"from": 2, "to": 10}, {"from": 6, "to": 10}, {"from": 1, "to": 2}, {"from": 7, "to": 5}, {"from": 1, "to": 9}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Added Labels

# %%
def generate_edge():
  s = random.randint(1,10)
  d = random.randint(1,10)
  return (s,d)

g_labels =  net.Network(height='600px',width='90%',
                  bgcolor='white',font_color="red",
                  heading="A Simple Networkx Graph with Labels")

for i in range(1,11):  
  g_labels.add_node(i,label=str(i))

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g_labels.add_edge(eg[0],eg[1])
      i+=1

g_labels.show('Simple_Network_Graph_labels.html')
display(HTML('Simple_Network_Graph_labels.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>A Simple Networkx Graph with Labels</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 90%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"font": {"color": "red"}, "id": 1, "label": "1", "shape": "dot"}, {"font": {"color": "red"}, "id": 2, "label": "2", "shape": "dot"}, {"font": {"color": "red"}, "id": 3, "label": "3", "shape": "dot"}, {"font": {"color": "red"}, "id": 4, "label": "4", "shape": "dot"}, {"font": {"color": "red"}, "id": 5, "label": "5", "shape": "dot"}, {"font": {"color": "red"}, "id": 6, "label": "6", "shape": "dot"}, {"font": {"color": "red"}, "id": 7, "label": "7", "shape": "dot"}, {"font": {"color": "red"}, "id": 8, "label": "8", "shape": "dot"}, {"font": {"color": "red"}, "id": 9, "label": "9", "shape": "dot"}, {"font": {"color": "red"}, "id": 10, "label": "10", "shape": "dot"}]);
#         edges = new vis.DataSet([{"from": 5, "to": 9}, {"from": 2, "to": 5}, {"from": 10, "to": 2}, {"from": 1, "to": 5}, {"from": 9, "to": 7}, {"from": 4, "to": 1}, {"from": 7, "to": 5}, {"from": 1, "to": 3}, {"from": 2, "to": 4}, {"from": 9, "to": 8}, {"from": 8, "to": 10}, {"from": 4, "to": 6}, {"from": 9, "to": 4}, {"from": 10, "to": 9}, {"from": 3, "to": 5}, {"from": 8, "to": 4}, {"from": 10, "to": 5}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Add Size of Nodes

# %%
def generate_size_node():
  v = random.randint(5,20)
  return v

g_sizes = net.Network(height='600px',width='90%',
                bgcolor='white',font_color="red",
                heading="Network Graph with Different Sizes")

for i in range(1,11):  
  val = generate_size_node()
  g_sizes.add_node(i,label=str(i),value=val)

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g_sizes.add_edge(eg[0],eg[1])
      i+=1

g_sizes.show('Simple_Network_Graph_sizes.html')
display(HTML('Simple_Network_Graph_sizes.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>Network Graph with Different Sizes</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 90%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"font": {"color": "red"}, "id": 1, "label": "1", "shape": "dot", "value": 11}, {"font": {"color": "red"}, "id": 2, "label": "2", "shape": "dot", "value": 15}, {"font": {"color": "red"}, "id": 3, "label": "3", "shape": "dot", "value": 5}, {"font": {"color": "red"}, "id": 4, "label": "4", "shape": "dot", "value": 14}, {"font": {"color": "red"}, "id": 5, "label": "5", "shape": "dot", "value": 11}, {"font": {"color": "red"}, "id": 6, "label": "6", "shape": "dot", "value": 10}, {"font": {"color": "red"}, "id": 7, "label": "7", "shape": "dot", "value": 18}, {"font": {"color": "red"}, "id": 8, "label": "8", "shape": "dot", "value": 7}, {"font": {"color": "red"}, "id": 9, "label": "9", "shape": "dot", "value": 7}, {"font": {"color": "red"}, "id": 10, "label": "10", "shape": "dot", "value": 18}]);
#         edges = new vis.DataSet([{"from": 1, "to": 6}, {"from": 5, "to": 4}, {"from": 9, "to": 6}, {"from": 8, "to": 10}, {"from": 7, "to": 3}, {"from": 3, "to": 5}, {"from": 1, "to": 4}, {"from": 7, "to": 8}, {"from": 7, "to": 2}, {"from": 8, "to": 5}, {"from": 4, "to": 7}, {"from": 7, "to": 1}, {"from": 7, "to": 6}, {"from": 3, "to": 6}, {"from": 10, "to": 3}, {"from": 5, "to": 1}, {"from": 2, "to": 1}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Added Colors

# %%
def generate_color():
  random_number = random.randint(0,16777215)
  hex_number = str(hex(random_number))
  hex_number ='#'+ hex_number[2:]
  return hex_number

g_colors =net.Network(height='600px',width='90%',
              bgcolor='white',font_color="red",
              heading="Network Graph with Different Colors")

colors=[]
for i in range(1,11):  
  c = generate_color()
  colors.append(c)
  while(c in colors):
      c = generate_color()
  colors.append(c)

  val = generate_size_node()

  g_colors.add_node(i,label=str(i),color=c,value=val)

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g_colors.add_edge(eg[0],eg[1])
      i+=1

g_colors.show('Simple_Network_Graph_colors.html')
display(HTML('Simple_Network_Graph_colors.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>Network Graph with Different Colors</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 90%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": "#34c73f", "font": {"color": "red"}, "id": 1, "label": "1", "shape": "dot", "value": 6}, {"color": "#a2af02", "font": {"color": "red"}, "id": 2, "label": "2", "shape": "dot", "value": 9}, {"color": "#d5f4ba", "font": {"color": "red"}, "id": 3, "label": "3", "shape": "dot", "value": 7}, {"color": "#29fe6e", "font": {"color": "red"}, "id": 4, "label": "4", "shape": "dot", "value": 6}, {"color": "#708cbc", "font": {"color": "red"}, "id": 5, "label": "5", "shape": "dot", "value": 18}, {"color": "#c1a901", "font": {"color": "red"}, "id": 6, "label": "6", "shape": "dot", "value": 8}, {"color": "#8d3024", "font": {"color": "red"}, "id": 7, "label": "7", "shape": "dot", "value": 7}, {"color": "#71c45c", "font": {"color": "red"}, "id": 8, "label": "8", "shape": "dot", "value": 16}, {"color": "#be0e0c", "font": {"color": "red"}, "id": 9, "label": "9", "shape": "dot", "value": 20}, {"color": "#bc8e72", "font": {"color": "red"}, "id": 10, "label": "10", "shape": "dot", "value": 10}]);
#         edges = new vis.DataSet([{"from": 1, "to": 7}, {"from": 10, "to": 8}, {"from": 1, "to": 3}, {"from": 7, "to": 9}, {"from": 4, "to": 6}, {"from": 7, "to": 4}, {"from": 9, "to": 1}, {"from": 5, "to": 8}, {"from": 8, "to": 6}, {"from": 9, "to": 10}, {"from": 3, "to": 10}, {"from": 1, "to": 4}, {"from": 10, "to": 5}, {"from": 1, "to": 6}, {"from": 7, "to": 8}, {"from": 8, "to": 1}, {"from": 3, "to": 5}, {"from": 5, "to": 1}, {"from": 9, "to": 8}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Added Shape of Nodes

# %%
def get_random_shape():
  shapes = ['box','polygon','triangle','circle','star','cylinder']
  r = random.randint(0,len(shapes)-1)
  return shapes[r]

g_shapes =net.Network(height='600px',width='90%',
              bgcolor='white',font_color="red",
              heading="Network Graph with Different Shapes")

colors=[]
for i in range(1,11):  
  c = generate_color()
  colors.append(c)
  while(c in colors):
      c = generate_color()
  colors.append(c)

  val = generate_size_node()
  s = get_random_shape()
  
  g_shapes.add_node(i,label=str(i),color=c,value=val,shape=s)

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g_shapes.add_edge(eg[0],eg[1])
      i+=1

g_shapes.show('Simple_Network_Graph_shapes.html')
display(HTML('Simple_Network_Graph_shapes.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>Network Graph with Different Shapes</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 90%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": "#88064", "font": {"color": "red"}, "id": 1, "label": "1", "shape": "star", "value": 7}, {"color": "#b76548", "font": {"color": "red"}, "id": 2, "label": "2", "shape": "box", "value": 19}, {"color": "#361965", "font": {"color": "red"}, "id": 3, "label": "3", "shape": "triangle", "value": 7}, {"color": "#8c43a5", "font": {"color": "red"}, "id": 4, "label": "4", "shape": "box", "value": 16}, {"color": "#41026b", "font": {"color": "red"}, "id": 5, "label": "5", "shape": "box", "value": 17}, {"color": "#40cb8f", "font": {"color": "red"}, "id": 6, "label": "6", "shape": "box", "value": 14}, {"color": "#cf5fff", "font": {"color": "red"}, "id": 7, "label": "7", "shape": "triangle", "value": 16}, {"color": "#64aa6d", "font": {"color": "red"}, "id": 8, "label": "8", "shape": "star", "value": 12}, {"color": "#1b8b3", "font": {"color": "red"}, "id": 9, "label": "9", "shape": "box", "value": 19}, {"color": "#92f4c8", "font": {"color": "red"}, "id": 10, "label": "10", "shape": "box", "value": 6}]);
#         edges = new vis.DataSet([{"from": 6, "to": 3}, {"from": 10, "to": 8}, {"from": 6, "to": 2}, {"from": 1, "to": 4}, {"from": 4, "to": 9}, {"from": 7, "to": 3}, {"from": 10, "to": 6}, {"from": 2, "to": 10}, {"from": 3, "to": 9}, {"from": 6, "to": 4}, {"from": 7, "to": 5}, {"from": 5, "to": 3}, {"from": 7, "to": 10}, {"from": 3, "to": 8}, {"from": 5, "to": 6}, {"from": 5, "to": 1}, {"from": 7, "to": 1}, {"from": 7, "to": 9}, {"from": 8, "to": 4}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Added Node BorderWidth

# %%
g_borders =net.Network(height='600px',width='90%',
              bgcolor='white',font_color="red",
              heading="Network Graph with Different BorderWidths")

colors=[]
for i in range(1,11):  
  c = generate_color()
  colors.append(c)
  while(c in colors):
      c = generate_color()
  colors.append(c)

  val = generate_size_node()
  s = get_random_shape()
  b = random.randint(3,5)

  g_borders.add_node(i,label=str(i),color=c,
                    value=val,shape=s,borderWidth=b)

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g_borders.add_edge(eg[0],eg[1])
      i+=1

g_borders.show('Simple_Network_Graph_Borders.html')
display(HTML('Simple_Network_Graph_Borders.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>Network Graph with Different BorderWidths</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 90%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"borderWidth": 3, "color": "#ee7907", "font": {"color": "red"}, "id": 1, "label": "1", "shape": "cylinder", "value": 13}, {"borderWidth": 4, "color": "#841bab", "font": {"color": "red"}, "id": 2, "label": "2", "shape": "polygon", "value": 14}, {"borderWidth": 4, "color": "#1a5064", "font": {"color": "red"}, "id": 3, "label": "3", "shape": "polygon", "value": 11}, {"borderWidth": 5, "color": "#66ceea", "font": {"color": "red"}, "id": 4, "label": "4", "shape": "circle", "value": 12}, {"borderWidth": 5, "color": "#ff23ae", "font": {"color": "red"}, "id": 5, "label": "5", "shape": "polygon", "value": 18}, {"borderWidth": 5, "color": "#330c27", "font": {"color": "red"}, "id": 6, "label": "6", "shape": "triangle", "value": 12}, {"borderWidth": 5, "color": "#ef61d3", "font": {"color": "red"}, "id": 7, "label": "7", "shape": "cylinder", "value": 15}, {"borderWidth": 3, "color": "#b38b6b", "font": {"color": "red"}, "id": 8, "label": "8", "shape": "star", "value": 12}, {"borderWidth": 5, "color": "#7814c0", "font": {"color": "red"}, "id": 9, "label": "9", "shape": "polygon", "value": 12}, {"borderWidth": 3, "color": "#1b1816", "font": {"color": "red"}, "id": 10, "label": "10", "shape": "cylinder", "value": 10}]);
#         edges = new vis.DataSet([{"from": 9, "to": 8}, {"from": 2, "to": 5}, {"from": 5, "to": 3}, {"from": 5, "to": 6}, {"from": 2, "to": 7}, {"from": 9, "to": 6}, {"from": 7, "to": 6}, {"from": 3, "to": 7}, {"from": 1, "to": 8}, {"from": 4, "to": 10}, {"from": 6, "to": 10}, {"from": 8, "to": 4}, {"from": 4, "to": 7}, {"from": 3, "to": 10}, {"from": 6, "to": 4}, {"from": 2, "to": 4}, {"from": 8, "to": 5}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Complete Networkx Graph

# %%
def generate_edge():
  s = random.randint(1,10)
  d = random.randint(1,10)
  return (s,d)

def generate_size_node():
  v = random.randint(5,20)
  return v

def generate_color():
  random_number = random.randint(0,16777215)
  hex_number = str(hex(random_number))
  hex_number ='#'+ hex_number[2:]
  return hex_number


g_complete =net.Network(height='600px',width='90%',
              bgcolor='white',font_color="red",notebook=True,
              heading="A Complete Networkx Graph")

colors=[]
for i in range(1,11):  
  c = generate_color()
  colors.append(c)
  while(c in colors):
      c = generate_color()
  colors.append(c)

  val = generate_size_node()
  b = random.randint(3,5)

  g_complete.add_node(i,label=str(i),color=c,value=val,
                      title="Hello! I am Node "+str(i),borderWidth=b)

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g_complete.add_edge(eg[0],eg[1])
      i+=1

g_complete.show('A_Complete_Networkx_Graph.html')
display(HTML('A_Complete_Networkx_Graph.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>A Complete Networkx Graph</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 90%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"borderWidth": 4, "color": "#206fe9", "font": {"color": "red"}, "id": 1, "label": "1", "shape": "dot", "title": "Hello! I am Node 1", "value": 11}, {"borderWidth": 4, "color": "#2288f1", "font": {"color": "red"}, "id": 2, "label": "2", "shape": "dot", "title": "Hello! I am Node 2", "value": 10}, {"borderWidth": 5, "color": "#c8d8c", "font": {"color": "red"}, "id": 3, "label": "3", "shape": "dot", "title": "Hello! I am Node 3", "value": 10}, {"borderWidth": 3, "color": "#72893c", "font": {"color": "red"}, "id": 4, "label": "4", "shape": "dot", "title": "Hello! I am Node 4", "value": 11}, {"borderWidth": 5, "color": "#860eaf", "font": {"color": "red"}, "id": 5, "label": "5", "shape": "dot", "title": "Hello! I am Node 5", "value": 7}, {"borderWidth": 3, "color": "#e38db3", "font": {"color": "red"}, "id": 6, "label": "6", "shape": "dot", "title": "Hello! I am Node 6", "value": 8}, {"borderWidth": 4, "color": "#47e8df", "font": {"color": "red"}, "id": 7, "label": "7", "shape": "dot", "title": "Hello! I am Node 7", "value": 15}, {"borderWidth": 5, "color": "#8447a0", "font": {"color": "red"}, "id": 8, "label": "8", "shape": "dot", "title": "Hello! I am Node 8", "value": 5}, {"borderWidth": 3, "color": "#116397", "font": {"color": "red"}, "id": 9, "label": "9", "shape": "dot", "title": "Hello! I am Node 9", "value": 10}, {"borderWidth": 3, "color": "#567742", "font": {"color": "red"}, "id": 10, "label": "10", "shape": "dot", "title": "Hello! I am Node 10", "value": 6}]);
#         edges = new vis.DataSet([{"from": 4, "to": 6}, {"from": 10, "to": 1}, {"from": 7, "to": 8}, {"from": 10, "to": 4}, {"from": 7, "to": 4}, {"from": 2, "to": 5}, {"from": 1, "to": 6}, {"from": 10, "to": 6}, {"from": 9, "to": 4}, {"from": 4, "to": 8}, {"from": 8, "to": 1}, {"from": 2, "to": 7}, {"from": 9, "to": 10}, {"from": 2, "to": 1}, {"from": 9, "to": 2}, {"from": 7, "to": 1}, {"from": 5, "to": 4}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": false
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Add Physics Buttons

# %%
def generate_edge():
  s = random.randint(1,10)
  d = random.randint(1,10)
  return (s,d)

def generate_size_node():
  v = random.randint(5,20)
  return v

def generate_color():
  random_number = random.randint(0,16777215)
  hex_number = str(hex(random_number))
  hex_number ='#'+ hex_number[2:]
  return hex_number


g_complete =net.Network(height='600px',width='50%',
              bgcolor='white',font_color="red",notebook=True,
              heading="A Complete Networkx Graph")

colors=[]
for i in range(1,11):  
  c = generate_color()
  colors.append(c)
  while(c in colors):
      c = generate_color()
  colors.append(c)

  val = generate_size_node()
  b = random.randint(3,5)

  g_complete.add_node(i,label=str(i),color=c,value=val,
                      title="Hello! I am Node "+str(i),borderWidth=b)

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g_complete.add_edge(eg[0],eg[1])
      i+=1

g_complete.show_buttons(['physics'])

g_complete.show('A_Complete_Networkx_Graph.html')
display(HTML('A_Complete_Networkx_Graph.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>A Complete Networkx Graph</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 50%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#         #config {
#             float: left;
#             width: 400px;
#             height: 600px;
#         }
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <div id = "config"></div>
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"borderWidth": 5, "color": "#6f87f6", "font": {"color": "red"}, "id": 1, "label": "1", "shape": "dot", "title": "Hello! I am Node 1", "value": 7}, {"borderWidth": 3, "color": "#7b5bc5", "font": {"color": "red"}, "id": 2, "label": "2", "shape": "dot", "title": "Hello! I am Node 2", "value": 14}, {"borderWidth": 4, "color": "#f79179", "font": {"color": "red"}, "id": 3, "label": "3", "shape": "dot", "title": "Hello! I am Node 3", "value": 16}, {"borderWidth": 3, "color": "#ddbae2", "font": {"color": "red"}, "id": 4, "label": "4", "shape": "dot", "title": "Hello! I am Node 4", "value": 14}, {"borderWidth": 4, "color": "#f08276", "font": {"color": "red"}, "id": 5, "label": "5", "shape": "dot", "title": "Hello! I am Node 5", "value": 17}, {"borderWidth": 4, "color": "#642abb", "font": {"color": "red"}, "id": 6, "label": "6", "shape": "dot", "title": "Hello! I am Node 6", "value": 14}, {"borderWidth": 4, "color": "#aba5cc", "font": {"color": "red"}, "id": 7, "label": "7", "shape": "dot", "title": "Hello! I am Node 7", "value": 17}, {"borderWidth": 3, "color": "#e3096b", "font": {"color": "red"}, "id": 8, "label": "8", "shape": "dot", "title": "Hello! I am Node 8", "value": 9}, {"borderWidth": 5, "color": "#c4d583", "font": {"color": "red"}, "id": 9, "label": "9", "shape": "dot", "title": "Hello! I am Node 9", "value": 18}, {"borderWidth": 5, "color": "#d0b5c7", "font": {"color": "red"}, "id": 10, "label": "10", "shape": "dot", "title": "Hello! I am Node 10", "value": 7}]);
#         edges = new vis.DataSet([{"from": 5, "to": 7}, {"from": 4, "to": 6}, {"from": 4, "to": 9}, {"from": 2, "to": 8}, {"from": 5, "to": 10}, {"from": 5, "to": 8}, {"from": 4, "to": 5}, {"from": 8, "to": 4}, {"from": 10, "to": 8}, {"from": 9, "to": 7}, {"from": 3, "to": 4}, {"from": 3, "to": 9}, {"from": 7, "to": 3}, {"from": 1, "to": 4}, {"from": 1, "to": 9}, {"from": 10, "to": 4}, {"from": 2, "to": 4}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": true,
#         "filter": [
#             "physics"
#         ]
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#         // if this network requires displaying the configure window,
#         // put it in its div
#         options.configure["container"] = document.getElementById("config");
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Directed Network Graph

# %%
def generate_edge():
  s = random.randint(1,10)
  d = random.randint(1,10)
  return (s,d)

def generate_size_node():
  v = random.randint(5,20)
  return v

def generate_color():
  random_number = random.randint(0,16777215)
  hex_number = str(hex(random_number))
  hex_number ='#'+ hex_number[2:]
  return hex_number


g_complete =net.Network(height='600px',width='50%',
              bgcolor='white',font_color="red",notebook=True,
              heading="A Complete Networkx Graph",directed=True)

colors=[]
for i in range(1,11):  
  c = generate_color()
  colors.append(c)
  while(c in colors):
      c = generate_color()
  colors.append(c)

  val = generate_size_node()
  b = random.randint(3,5)

  g_complete.add_node(i,label=str(i),color=c,value=val,
                      title="Hello! I am Node "+str(i),borderWidth=b)

i=0
chosen_set = []
while(i!=20):
  eg = generate_edge()
  if(eg[0]!=eg[1] and not (eg in chosen_set)):
      chosen_set.append(eg)
      g_complete.add_edge(eg[0],eg[1])
      i+=1

g_complete.show_buttons(['physics'])

g_complete.show('A_Complete_Networkx_Graph.html')
display(HTML('A_Complete_Networkx_Graph.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>A Complete Networkx Graph</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 50%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#         #config {
#             float: left;
#             width: 400px;
#             height: 600px;
#         }
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <div id = "config"></div>
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"borderWidth": 5, "color": "#801907", "font": {"color": "red"}, "id": 1, "label": "1", "shape": "dot", "title": "Hello! I am Node 1", "value": 8}, {"borderWidth": 4, "color": "#b2308e", "font": {"color": "red"}, "id": 2, "label": "2", "shape": "dot", "title": "Hello! I am Node 2", "value": 13}, {"borderWidth": 5, "color": "#20d1ab", "font": {"color": "red"}, "id": 3, "label": "3", "shape": "dot", "title": "Hello! I am Node 3", "value": 9}, {"borderWidth": 5, "color": "#3cbbdb", "font": {"color": "red"}, "id": 4, "label": "4", "shape": "dot", "title": "Hello! I am Node 4", "value": 16}, {"borderWidth": 4, "color": "#ab8670", "font": {"color": "red"}, "id": 5, "label": "5", "shape": "dot", "title": "Hello! I am Node 5", "value": 12}, {"borderWidth": 3, "color": "#d9530", "font": {"color": "red"}, "id": 6, "label": "6", "shape": "dot", "title": "Hello! I am Node 6", "value": 18}, {"borderWidth": 5, "color": "#f0f141", "font": {"color": "red"}, "id": 7, "label": "7", "shape": "dot", "title": "Hello! I am Node 7", "value": 18}, {"borderWidth": 5, "color": "#4f0f89", "font": {"color": "red"}, "id": 8, "label": "8", "shape": "dot", "title": "Hello! I am Node 8", "value": 17}, {"borderWidth": 5, "color": "#ad464a", "font": {"color": "red"}, "id": 9, "label": "9", "shape": "dot", "title": "Hello! I am Node 9", "value": 17}, {"borderWidth": 4, "color": "#c0f1ea", "font": {"color": "red"}, "id": 10, "label": "10", "shape": "dot", "title": "Hello! I am Node 10", "value": 20}]);
#         edges = new vis.DataSet([{"arrows": "to", "from": 6, "to": 8}, {"arrows": "to", "from": 1, "to": 3}, {"arrows": "to", "from": 7, "to": 9}, {"arrows": "to", "from": 7, "to": 6}, {"arrows": "to", "from": 1, "to": 8}, {"arrows": "to", "from": 3, "to": 5}, {"arrows": "to", "from": 9, "to": 5}, {"arrows": "to", "from": 3, "to": 6}, {"arrows": "to", "from": 5, "to": 4}, {"arrows": "to", "from": 9, "to": 1}, {"arrows": "to", "from": 3, "to": 1}, {"arrows": "to", "from": 5, "to": 1}, {"arrows": "to", "from": 2, "to": 8}, {"arrows": "to", "from": 4, "to": 9}, {"arrows": "to", "from": 4, "to": 7}, {"arrows": "to", "from": 2, "to": 4}, {"arrows": "to", "from": 7, "to": 1}, {"arrows": "to", "from": 10, "to": 8}, {"arrows": "to", "from": 6, "to": 3}, {"arrows": "to", "from": 7, "to": 10}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": true,
#         "filter": [
#             "physics"
#         ]
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#         // if this network requires displaying the configure window,
#         // put it in its div
#         options.configure["container"] = document.getElementById("config");
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>

# %% [markdown]
# # Network Graph From Pandas Dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv('routes.csv')
df = df[['Source airport','Destination airport']]
df = df[:500]
df.head()
# Out:
#   Source airport Destination airport
# 0            AER                 KZN
# 1            ASF                 KZN
# 2            ASF                 MRV
# 3            CEK                 KZN
# 4            CEK                 OVB

# %%
sources = list(df['Source airport'])
destinations = list(df['Destination airport'])

g_from_data =net.Network(height='600px',width='50%',
              bgcolor='white',font_color="black",
              heading="A Networkx Graph from DataFrame",directed=True)

for i in range(len(sources)):
  try:
    g_from_data.add_node(sources[i],label=sources[i],title=sources[i])
  except:
    pass

for (i,j) in zip(sources,destinations):
    try:
      g_from_data.add_edge(i,j)
    except:
      pass

g_from_data.show_buttons(['physics'])

g_from_data.show('A_Complete_Networkx_Graph_From_DataFrame.html')
display(HTML('A_Complete_Networkx_Graph_From_DataFrame.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>A Networkx Graph from DataFrame</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 50%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#         #loadingBar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width: 50%;
#             height: 600px;
#             background-color:rgba(200,200,200,0.8);
#             -webkit-transition: all 0.5s ease;
#             -moz-transition: all 0.5s ease;
#             -ms-transition: all 0.5s ease;
#             -o-transition: all 0.5s ease;
#             transition: all 0.5s ease;
#             opacity:1;
#         }
#
#         #bar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width:20px;
#             height:20px;
#             margin:auto auto auto auto;
#             border-radius:11px;
#             border:2px solid rgba(30,30,30,0.05);
#             background: rgb(0, 173, 246); /* Old browsers */
#             box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#         }
#
#         #border {
#             position:absolute;
#             top:10px;
#             left:10px;
#             width:500px;
#             height:23px;
#             margin:auto auto auto auto;
#             box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#             border-radius:10px;
#         }
#
#         #text {
#             position:absolute;
#             top:8px;
#             left:530px;
#             width:30px;
#             height:50px;
#             margin:auto auto auto auto;
#             font-size:22px;
#             color: #000000;
#         }
#
#         div.outerBorder {
#             position:relative;
#             top:400px;
#             width:600px;
#             height:44px;
#             margin:auto auto auto auto;
#             border:8px solid rgba(0,0,0,0.1);
#             background: rgb(252,252,252); /* Old browsers */
#             background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#             background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#             background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#             background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#             background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#             background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#             filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#             border-radius:72px;
#             box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#         }
#
#
#
#         #config {
#             float: left;
#             width: 400px;
#             height: 600px;
#         }
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
# <div id="loadingBar">
#     <div class="outerBorder">
#         <div id="text">0%</div>
#         <div id="border">
#             <div id="bar"></div>
#         </div>
#     </div>
# </div>
#
#
# <div id = "config"></div>
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"font": {"color": "black"}, "id": "AER", "label": "AER", "shape": "dot", "title": "AER"}, {"font": {"color": "black"}, "id": "ASF", "label": "ASF", "shape": "dot", "title": "ASF"}, {"font": {"color": "black"}, "id": "CEK", "label": "CEK", "shape": "dot", "title": "CEK"}, {"font": {"color": "black"}, "id": "DME", "label": "DME", "shape": "dot", "title": "DME"}, {"font": {"color": "black"}, "id": "EGO", "label": "EGO", "shape": "dot", "title": "EGO"}, {"font": {"color": "black"}, "id": "GYD", "label": "GYD", "shape": "dot", "title": "GYD"}, {"font": {"color": "black"}, "id": "KGD", "label": "KGD", "shape": "dot", "title": "KGD"}, {"font": {"color": "black"}, "id": "KZN", "label": "KZN", "shape": "dot", "title": "KZN"}, {"font": {"color": "black"}, "id": "LED", "label": "LED", "shape": "dot", "title": "LED"}, {"font": {"color": "black"}, "id": "MRV", "label": "MRV", "shape": "dot", "title": "MRV"}, {"font": {"color": "black"}, "id": "NBC", "label": "NBC", "shape": "dot", "title": "NBC"}, {"font": {"color": "black"}, "id": "NJC", "label": "NJC", "shape": "dot", "title": "NJC"}, {"font": {"color": "black"}, "id": "NUX", "label": "NUX", "shape": "dot", "title": "NUX"}, {"font": {"color": "black"}, "id": "OVB", "label": "OVB", "shape": "dot", "title": "OVB"}, {"font": {"color": "black"}, "id": "SVX", "label": "SVX", "shape": "dot", "title": "SVX"}, {"font": {"color": "black"}, "id": "TGK", "label": "TGK", "shape": "dot", "title": "TGK"}, {"font": {"color": "black"}, "id": "UUA", "label": "UUA", "shape": "dot", "title": "UUA"}, {"font": {"color": "black"}, "id": "BTK", "label": "BTK", "shape": "dot", "title": "BTK"}, {"font": {"color": "black"}, "id": "HTA", "label": "HTA", "shape": "dot", "title": "HTA"}, {"font": {"color": "black"}, "id": "IKT", "label": "IKT", "shape": "dot", "title": "IKT"}, {"font": {"color": "black"}, "id": "KCK", "label": "KCK", "shape": "dot", "title": "KCK"}, {"font": {"color": "black"}, "id": "MJZ", "label": "MJZ", "shape": "dot", "title": "MJZ"}, {"font": {"color": "black"}, "id": "ODO", "label": "ODO", "shape": "dot", "title": "ODO"}, {"font": {"color": "black"}, "id": "UKX", "label": "UKX", "shape": "dot", "title": "UKX"}, {"font": {"color": "black"}, "id": "ULK", "label": "ULK", "shape": "dot", "title": "ULK"}, {"font": {"color": "black"}, "id": "YKS", "label": "YKS", "shape": "dot", "title": "YKS"}, {"font": {"color": "black"}, "id": "AYP", "label": "AYP", "shape": "dot", "title": "AYP"}, {"font": {"color": "black"}, "id": "CUZ", "label": "CUZ", "shape": "dot", "title": "CUZ"}, {"font": {"color": "black"}, "id": "HUU", "label": "HUU", "shape": "dot", "title": "HUU"}, {"font": {"color": "black"}, "id": "IQT", "label": "IQT", "shape": "dot", "title": "IQT"}, {"font": {"color": "black"}, "id": "LIM", "label": "LIM", "shape": "dot", "title": "LIM"}, {"font": {"color": "black"}, "id": "PCL", "label": "PCL", "shape": "dot", "title": "PCL"}, {"font": {"color": "black"}, "id": "PEM", "label": "PEM", "shape": "dot", "title": "PEM"}, {"font": {"color": "black"}, "id": "TPP", "label": "TPP", "shape": "dot", "title": "TPP"}, {"font": {"color": "black"}, "id": "ABJ", "label": "ABJ", "shape": "dot", "title": "ABJ"}, {"font": {"color": "black"}, "id": "ACC", "label": "ACC", "shape": "dot", "title": "ACC"}, {"font": {"color": "black"}, "id": "BKO", "label": "BKO", "shape": "dot", "title": "BKO"}, {"font": {"color": "black"}, "id": "BOY", "label": "BOY", "shape": "dot", "title": "BOY"}, {"font": {"color": "black"}, "id": "COO", "label": "COO", "shape": "dot", "title": "COO"}, {"font": {"color": "black"}, "id": "DKR", "label": "DKR", "shape": "dot", "title": "DKR"}, {"font": {"color": "black"}, "id": "LFW", "label": "LFW", "shape": "dot", "title": "LFW"}, {"font": {"color": "black"}, "id":

# %%
import pandas as pd

df = pd.read_csv('routes.csv')
df = df[['Source airport','Destination airport']]
df = df[:1000]
df.head()

sources = list(df['Source airport'])
destinations = list(df['Destination airport'])

g_from_data =net.Network(height='600px',width='50%',
              bgcolor='white',font_color="black",
              heading="A Networkx Graph from DataFrame",directed=True)

for i in range(len(sources)):
  try:
    g_from_data.add_node(sources[i],label=sources[i],title=sources[i])
  except:
    pass

for (i,j) in zip(sources,destinations):
    try:
      g_from_data.add_edge(i,j)
    except:
      pass

g_from_data.show_buttons(['physics'])

g_from_data.show('A_Complete_Networkx_Graph_From_DataFrame.html')
display(HTML('A_Complete_Networkx_Graph_From_DataFrame.html'))
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1>A Networkx Graph from DataFrame</h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 50%;
#             height: 600px;
#             background-color: white;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#         #loadingBar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width: 50%;
#             height: 600px;
#             background-color:rgba(200,200,200,0.8);
#             -webkit-transition: all 0.5s ease;
#             -moz-transition: all 0.5s ease;
#             -ms-transition: all 0.5s ease;
#             -o-transition: all 0.5s ease;
#             transition: all 0.5s ease;
#             opacity:1;
#         }
#
#         #bar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width:20px;
#             height:20px;
#             margin:auto auto auto auto;
#             border-radius:11px;
#             border:2px solid rgba(30,30,30,0.05);
#             background: rgb(0, 173, 246); /* Old browsers */
#             box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#         }
#
#         #border {
#             position:absolute;
#             top:10px;
#             left:10px;
#             width:500px;
#             height:23px;
#             margin:auto auto auto auto;
#             box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#             border-radius:10px;
#         }
#
#         #text {
#             position:absolute;
#             top:8px;
#             left:530px;
#             width:30px;
#             height:50px;
#             margin:auto auto auto auto;
#             font-size:22px;
#             color: #000000;
#         }
#
#         div.outerBorder {
#             position:relative;
#             top:400px;
#             width:600px;
#             height:44px;
#             margin:auto auto auto auto;
#             border:8px solid rgba(0,0,0,0.1);
#             background: rgb(252,252,252); /* Old browsers */
#             background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#             background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#             background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#             background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#             background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#             background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#             filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#             border-radius:72px;
#             box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#         }
#
#
#
#         #config {
#             float: left;
#             width: 400px;
#             height: 600px;
#         }
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
# <div id="loadingBar">
#     <div class="outerBorder">
#         <div id="text">0%</div>
#         <div id="border">
#             <div id="bar"></div>
#         </div>
#     </div>
# </div>
#
#
# <div id = "config"></div>
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"font": {"color": "black"}, "id": "AER", "label": "AER", "shape": "dot", "title": "AER"}, {"font": {"color": "black"}, "id": "ASF", "label": "ASF", "shape": "dot", "title": "ASF"}, {"font": {"color": "black"}, "id": "CEK", "label": "CEK", "shape": "dot", "title": "CEK"}, {"font": {"color": "black"}, "id": "DME", "label": "DME", "shape": "dot", "title": "DME"}, {"font": {"color": "black"}, "id": "EGO", "label": "EGO", "shape": "dot", "title": "EGO"}, {"font": {"color": "black"}, "id": "GYD", "label": "GYD", "shape": "dot", "title": "GYD"}, {"font": {"color": "black"}, "id": "KGD", "label": "KGD", "shape": "dot", "title": "KGD"}, {"font": {"color": "black"}, "id": "KZN", "label": "KZN", "shape": "dot", "title": "KZN"}, {"font": {"color": "black"}, "id": "LED", "label": "LED", "shape": "dot", "title": "LED"}, {"font": {"color": "black"}, "id": "MRV", "label": "MRV", "shape": "dot", "title": "MRV"}, {"font": {"color": "black"}, "id": "NBC", "label": "NBC", "shape": "dot", "title": "NBC"}, {"font": {"color": "black"}, "id": "NJC", "label": "NJC", "shape": "dot", "title": "NJC"}, {"font": {"color": "black"}, "id": "NUX", "label": "NUX", "shape": "dot", "title": "NUX"}, {"font": {"color": "black"}, "id": "OVB", "label": "OVB", "shape": "dot", "title": "OVB"}, {"font": {"color": "black"}, "id": "SVX", "label": "SVX", "shape": "dot", "title": "SVX"}, {"font": {"color": "black"}, "id": "TGK", "label": "TGK", "shape": "dot", "title": "TGK"}, {"font": {"color": "black"}, "id": "UUA", "label": "UUA", "shape": "dot", "title": "UUA"}, {"font": {"color": "black"}, "id": "BTK", "label": "BTK", "shape": "dot", "title": "BTK"}, {"font": {"color": "black"}, "id": "HTA", "label": "HTA", "shape": "dot", "title": "HTA"}, {"font": {"color": "black"}, "id": "IKT", "label": "IKT", "shape": "dot", "title": "IKT"}, {"font": {"color": "black"}, "id": "KCK", "label": "KCK", "shape": "dot", "title": "KCK"}, {"font": {"color": "black"}, "id": "MJZ", "label": "MJZ", "shape": "dot", "title": "MJZ"}, {"font": {"color": "black"}, "id": "ODO", "label": "ODO", "shape": "dot", "title": "ODO"}, {"font": {"color": "black"}, "id": "UKX", "label": "UKX", "shape": "dot", "title": "UKX"}, {"font": {"color": "black"}, "id": "ULK", "label": "ULK", "shape": "dot", "title": "ULK"}, {"font": {"color": "black"}, "id": "YKS", "label": "YKS", "shape": "dot", "title": "YKS"}, {"font": {"color": "black"}, "id": "AYP", "label": "AYP", "shape": "dot", "title": "AYP"}, {"font": {"color": "black"}, "id": "CUZ", "label": "CUZ", "shape": "dot", "title": "CUZ"}, {"font": {"color": "black"}, "id": "HUU", "label": "HUU", "shape": "dot", "title": "HUU"}, {"font": {"color": "black"}, "id": "IQT", "label": "IQT", "shape": "dot", "title": "IQT"}, {"font": {"color": "black"}, "id": "LIM", "label": "LIM", "shape": "dot", "title": "LIM"}, {"font": {"color": "black"}, "id": "PCL", "label": "PCL", "shape": "dot", "title": "PCL"}, {"font": {"color": "black"}, "id": "PEM", "label": "PEM", "shape": "dot", "title": "PEM"}, {"font": {"color": "black"}, "id": "TPP", "label": "TPP", "shape": "dot", "title": "TPP"}, {"font": {"color": "black"}, "id": "ABJ", "label": "ABJ", "shape": "dot", "title": "ABJ"}, {"font": {"color": "black"}, "id": "ACC", "label": "ACC", "shape": "dot", "title": "ACC"}, {"font": {"color": "black"}, "id": "BKO", "label": "BKO", "shape": "dot", "title": "BKO"}, {"font": {"color": "black"}, "id": "BOY", "label": "BOY", "shape": "dot", "title": "BOY"}, {"font": {"color": "black"}, "id": "COO", "label": "COO", "shape": "dot", "title": "COO"}, {"font": {"color": "black"}, "id": "DKR", "label": "DKR", "shape": "dot", "title": "DKR"}, {"font": {"color": "black"}, "id": "LFW", "label": "LFW", "shape": "dot", "title": "LFW"}, {"font": {"color": "black"}, "id":
