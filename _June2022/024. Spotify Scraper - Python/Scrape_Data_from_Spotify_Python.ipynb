# %% [markdown]
# # Scrape Data from Spotify - Python

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %%
client_id = 'ed4fc812064b4d609b3d4dceb4fce670'
client_secret = 'bfba15c793034aeb84f6244473b28f9f'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

ids = getTrackIDs('Taylor Swift', '4GtQVhGjAwcHFz82UKy3Ca')

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("spotify.csv", sep = ',')

# %%
df.head()
# Out:
#                                                 name  \
# 0                       This Love (Taylor’s Version)
# 1                  Wildest Dreams (Taylor's Version)
# 2  All Too Well (10 Minute Version) (The Short Film)
# 3       The Joker And The Queen (feat. Taylor Swift)
# 4  Message In A Bottle (Fat Max G Remix) (Taylor’...
#
#                                                album        artist  \
# 0                       This Love (Taylor’s Version)  Taylor Swift
# 1                       This Love (Taylor’s Version)  Taylor Swift
# 2  All Too Well (10 Minute Version) (The Short Film)  Taylor Swift
# 3       The Joker And The Queen (feat. Taylor Swift)    Ed Sheeran
# 4  Message In A Bottle (Fat Max G Remix) (Taylor’...  Taylor Swift
#
#   release_date  length  popularity  danceability  acousticness  danceability  \
# 0   2022-05-06  250100          82         0.470       0.30200         0.470
# 1   2022-05-06  220433          68         0.587       0.03540         0.587
# 2   2022-06-11  686022          65         0.625       0.32300         0.625
# 3   2022-02-11  185422          78         0.528       0.92400         0.528
# 4   2022-01-21  224649          61         0.684       0.00226         0.684
#
#    energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0   0.494          0.000000    0.0672    -8.672       0.0349  144.039
# 1   0.663          0.000091    0.0902    -7.423       0.0599  139.990
# 2   0.515          0.000035    0.0764   -10.202       0.0281   93.021
# 3   0.309          0.000002    0.2820    -7.398       0.0329  133.830
# 4   0.733          0.000125    0.2730    -4.203       0.0422  115.969
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
